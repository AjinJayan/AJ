# %% [markdown]
# <a href="https://colab.research.google.com/github/AjinJayan/AJ/blob/master/transfer_learning_dog_cat.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !unzip -q "/content/drive/My Drive/train.zip"

# %%
import glob
import numpy as np
import os
import shutil
import pandas as pd
np.random.seed(42)

# %%
files = glob.glob('train/*')

cat_files = [fn for fn in files if 'cat' in fn]
dog_files = [fn for fn in files if 'dog' in fn]
len(cat_files), len(dog_files)
# Out:
# (2503, 2504)

# %%
cat_train = np.random.choice(cat_files, size=1500, replace=False)
dog_train = np.random.choice(dog_files, size=1500, replace=False)
cat_files = list(set(cat_files) - set(cat_train))
dog_files = list(set(dog_files) - set(dog_train))

cat_val = np.random.choice(cat_files, size=500, replace=False)
dog_val = np.random.choice(dog_files, size=500, replace=False)
cat_files = list(set(cat_files) - set(cat_val))
dog_files = list(set(dog_files) - set(dog_val))

cat_test = np.random.choice(cat_files, size=500, replace=False)
dog_test = np.random.choice(dog_files, size=500, replace=False)

print('Cat datasets:', cat_train.shape, cat_val.shape, cat_test.shape)
print('Dog datasets:', dog_train.shape, dog_val.shape, dog_test.shape)
# Out:
# Cat datasets: (1500,) (500,) (500,)
# Dog datasets: (1500,) (500,) (500,)

# %%
train_dir = 'training_data'
val_dir = 'validation_data'
test_dir = 'test_data'

train_files = np.concatenate([cat_train, dog_train])
validate_files = np.concatenate([cat_val, dog_val])
test_files = np.concatenate([cat_test, dog_test])

os.mkdir(train_dir) if not os.path.isdir(train_dir) else None
os.mkdir(val_dir) if not os.path.isdir(val_dir) else None
os.mkdir(test_dir) if not os.path.isdir(test_dir) else None

for fn in train_files:
    shutil.copy(fn, train_dir)

for fn in validate_files:
    shutil.copy(fn, val_dir)
    
for fn in test_files:
    shutil.copy(fn, test_dir)

# %%
import matplotlib.pyplot as plt
from keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array, array_to_img
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
IMG_DIM = (150, 150)

train_files = glob.glob('training_data/*')
train_imgs = [img_to_array(load_img(img, target_size=IMG_DIM)) for img in train_files]
train_imgs = np.array(train_imgs)
train_labels = [fn.split('/')[1].split('.')[0].strip() for fn in train_files]

validation_files = glob.glob('validation_data/*')
validation_imgs = [img_to_array(load_img(img, target_size=IMG_DIM)) for img in validation_files]
validation_imgs = np.array(validation_imgs)
validation_labels = [fn.split('/')[1].split('.')[0].strip() for fn in validation_files]

print('Train dataset shape:', train_imgs.shape, 
      '\tValidation dataset shape:', validation_imgs.shape)
# Out:
# Train dataset shape: (3000, 150, 150, 3) 	Validation dataset shape: (1000, 150, 150, 3)

# %%
train_imgs_scaled = train_imgs.astype('float32')
validation_imgs_scaled  = validation_imgs.astype('float32')
train_imgs_scaled /= 255
validation_imgs_scaled /= 255

print(train_imgs[0].shape)
array_to_img(train_imgs[0])
# Out:
# (150, 150, 3)
# <PIL.Image.Image image mode=RGB size=150x150 at 0x7F8BBC142B70>

# %%
batch_size = 30
num_classes = 2
epochs = 30
input_shape = (150, 150, 3)

from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
le.fit(train_labels)
train_labels_enc = le.transform(train_labels)
validation_labels_enc = le.transform(validation_labels)

print(train_labels[1495:1505], train_labels_enc[1495:1505])
# Out:
# ['dog', 'dog', 'dog', 'dog', 'cat', 'cat', 'dog', 'cat', 'cat', 'cat'] [1 1 1 1 0 0 1 0 0 0]

# %%
import tensorflow as tf
from tensorflow.keras.applications import vgg16
from tensorflow.keras.models import Model
from tensorflow import keras

vgg = vgg16.VGG16(include_top=False, weights='imagenet', 
                                     input_shape=input_shape)

output = vgg.layers[-1].output
output = keras.layers.Flatten()(output)
vgg_model = Model(vgg.input, output)

vgg_model.trainable = True

set_trainable = False
for layer in vgg_model.layers:
    if layer.name in ['block5_conv1', 'block4_conv1']:
        set_trainable = True
    if set_trainable:
        layer.trainable = True
    else:
        layer.trainable = False
        
layers = [(layer, layer.name, layer.trainable) for layer in vgg_model.layers]
pd.DataFrame(layers, columns=['Layer Type', 'Layer Name', 'Layer Trainable'])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58892288/58889256 [==============================] - 1s 0us/step
#                                            Layer Type  ... Layer Trainable
# 0   <tensorflow.python.keras.engine.input_layer.In...  ...           False
# 1   <tensorflow.python.keras.layers.convolutional....  ...           False
# 2   <tensorflow.python.keras.layers.convolutional....  ...           False
# 3   <tensorflow.python.keras.layers.pooling.MaxPoo...  ...           False
# 4   <tensorflow.python.keras.layers.convolutional....  ...           False
# 5   <tensorflow.python.keras.layers.convolutional....  ...           False
# 6   <tensorflow.python.keras.layers.pooling.MaxPoo...  ...           False
# 7   <tensorflow.python.keras.layers.convolutional....  ...           False
# 8   <tensorflow.python.keras.layers.convolutional....  ...           False
# 9   <tensorflow.python.keras.layers.convolutional....  ...           False
# 10  <tensorflow.python.keras.layers.pooling.MaxPoo...  ...           False
# 11  <tensorflow.python.keras.layers.convolutional....  ...            True
# 12  <tensorflow.python.keras.layers.convolutional....  ...            True
# 13  <tensorflow.python.keras.layers.convolutional....  ...            True
# 14  <tensorflow.python.keras.layers.pooling.MaxPoo...  ...            True
# 15  <tensorflow.python.keras.layers.convolutional....  ...            True
# 16  <tensorflow.python.keras.layers.convolutional....  ...            True
# 17  <tensorflow.python.keras.layers.convolutional....  ...            True
# 18  <tensorflow.python.keras.layers.pooling.MaxPoo...  ...            True
# 19  <tensorflow.python.keras.layers.core.Flatten o...  ...            True
#
# [20 rows x 3 columns]

# %%
bottleneck_feature_example = vgg.predict(train_imgs_scaled[0:1])
print(bottleneck_feature_example.shape)
plt.imshow(bottleneck_feature_example[0][:,:,0])
# Out:
# (1, 4, 4, 512)

# %%
def get_bottleneck_features(model, input_imgs):
    features = model.predict(input_imgs, verbose=0)
    return features
    
train_features_vgg = get_bottleneck_features(vgg_model, train_imgs_scaled)
validation_features_vgg = get_bottleneck_features(vgg_model, validation_imgs_scaled)

print('Train Bottleneck Features:', train_features_vgg.shape, 
      '\tValidation Bottleneck Features:', validation_features_vgg.shape)
# Out:
# Train Bottleneck Features: (3000, 8192) 	Validation Bottleneck Features: (1000, 8192)

# %%
train_datagen = ImageDataGenerator(rescale=1./255, zoom_range=0.3, rotation_range=50,
                                   width_shift_range=0.2, height_shift_range=0.2, shear_range=0.2, 
                                   horizontal_flip=True, fill_mode='nearest')

val_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow(train_imgs, train_labels_enc, batch_size=30)
val_generator = val_datagen.flow(validation_imgs, validation_labels_enc, batch_size=20)

# %%
img_id = 2595
cat_generator = train_datagen.flow(train_imgs[img_id:img_id+1], train_labels[img_id:img_id+1],
                                   batch_size=1)
cat = [next(cat_generator) for i in range(0,5)]
fig, ax = plt.subplots(1,5, figsize=(16, 6))
print('Labels:', [item[1][0] for item in cat])
l = [ax[i].imshow(cat[i][0][0]) for i in range(0,5)]
# Out:
# Labels: ['cat', 'cat', 'cat', 'cat', 'cat']

# %%
img_id = 1991
dog_generator = train_datagen.flow(train_imgs[img_id:img_id+1], train_labels[img_id:img_id+1],
                                   batch_size=1)
dog = [next(dog_generator) for i in range(0,5)]
fig, ax = plt.subplots(1,5, figsize=(15, 6))
print('Labels:', [item[1][0] for item in dog])
l = [ax[i].imshow(dog[i][0][0]) for i in range(0,5)]
# Out:
# Labels: ['cat', 'cat', 'cat', 'cat', 'cat']

# %%
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, InputLayer
from tensorflow.keras.models import Sequential
from tensorflow.keras import optimizers

model = Sequential()
model.add(vgg_model)
model.add(Dense(512, activation='relu', input_dim=input_shape))
model.add(Dropout(0.3))
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(1, activation='sigmoid'))

model.compile(loss='binary_crossentropy',
              optimizer=optimizers.RMSprop(lr=1e-5),
              metrics=['accuracy'])
              
history = model.fit_generator(train_generator, steps_per_epoch=100, epochs=100,
                              validation_data=val_generator, validation_steps=50, 
                              verbose=1)
# Out:
# WARNING:tensorflow:From <ipython-input-21-a97148d9248a>:19: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# Epoch 1/100
# 100/100 [==============================] - 24s 244ms/step - loss: 0.5938 - accuracy: 0.6750 - val_loss: 0.3820 - val_accuracy: 0.8370
# Epoch 2/100
# 100/100 [==============================] - 23s 231ms/step - loss: 0.3968 - accuracy: 0.8207 - val_loss: 0.2064 - val_accuracy: 0.9080
# Epoch 3/100
# 100/100 [==============================] - 23s 234ms/step - loss: 0.3382 - accuracy: 0.8507 - val_loss: 0.1687 - val_accuracy: 0.9280
# Epoch 4/100
# 100/100 [==============================] - 23s 234ms/step - loss: 0.2843 - accuracy: 0.8810 - val_loss: 0.1716 - val_accuracy: 0.9250
# Epoch 5/100
# 100/100 [==============================] - 24s 236ms/step - loss: 0.2531 - accuracy: 0.8917 - val_loss: 0.1429 - val_accuracy: 0.9350
# Epoch 6/100
# 100/100 [==============================] - 24s 236ms/step - loss: 0.2323 - accuracy: 0.9033 - val_loss: 0.1236 - val_accuracy: 0.9530
# Epoch 7/100
# 100/100 [==============================] - 24s 236ms/step - loss: 0.2139 - accuracy: 0.9123 - val_loss: 0.1836 - val_accuracy: 0.9320
# Epoch 8/100
# 100/100 [==============================] - 24s 237ms/step - loss: 0.1901 - accuracy: 0.9257 - val_loss: 0.1713 - val_accuracy: 0.9390
# Epoch 9/100
# 100/100 [==============================] - 24s 236ms/step - loss: 0.1889 - accuracy: 0.9243 - val_loss: 0.1421 - val_accuracy: 0.9410
# Epoch 10/100
# 100/100 [==============================] - 24s 237ms/step - loss: 0.1721 - accuracy: 0.9313 - val_loss: 0.1172 - val_accuracy: 0.9570
# Epoch 11/100
# 100/100 [==============================] - 24s 239ms/step - loss: 0.1651 - accuracy: 0.9350 - val_loss: 0.1168 - val_accuracy: 0.9580
# Epoch 12/100
# 100/100 [==============================] - 24s 237ms/step - loss: 0.1492 - accuracy: 0.9427 - val_loss: 0.1265 - val_accuracy: 0.9520
# Epoch 13/100
# 100/100 [==============================] - 24s 236ms/step - loss: 0.1387 - accuracy: 0.9420 - val_loss: 0.1971 - val_accuracy: 0.9350
# Epoch 14/100
# 100/100 [==============================] - 24s 241ms/step - loss: 0.1259 - accuracy: 0.9503 - val_loss: 0.1231 - val_accuracy: 0.9660
# Epoch 15/100
# 100/100 [==============================] - 24s 241ms/step - loss: 0.1331 - accuracy: 0.9527 - val_loss: 0.1186 - val_accuracy: 0.9610
# Epoch 16/100
# 100/100 [==============================] - 24s 241ms/step - loss: 0.1284 - accuracy: 0.9460 - val_loss: 0.1852 - val_accuracy: 0.9410
# Epoch 17/100
# 100/100 [==============================] - 24s 239ms/step - loss: 0.1054 - accuracy: 0.9553 - val_loss: 0.2325 - val_accuracy: 0.9350
# Epoch 18/100
# 100/100 [==============================] - 24s 238ms/step - loss: 0.1191 - accuracy: 0.9530 - val_loss: 0.1417 - val_accuracy: 0.9590
# Epoch 19/100
# 100/100 [==============================] - 24s 237ms/step - loss: 0.1137 - accuracy: 0.9590 - val_loss: 0.1838 - val_accuracy: 0.9420
# Epoch 20/100
# 100/100 [==============================] - 24s 239ms/step - loss: 0.1114 - accuracy: 0.9600 - val_loss: 0.0897 - val_accuracy: 0.9690
# Epoch 21/100
# 100/100 [==============================] - 24s 239ms/step - loss: 0.0984 - accuracy: 0.9587 - val_loss: 0.1318 - val_accuracy: 0.9570
# Epoch 22/100
# 100/100 [==============================] - 24s 239ms/step - loss: 0.0909 - accuracy: 0.9627 - val_loss: 0.1266 - val_accuracy: 0.9630
# Epoch 23/100
# 100/100 [==============================] - 24s 236ms/step - loss: 0.0870 - accuracy: 0.9657 - val_loss: 0.1237 - val_accuracy: 0.9540
# Epoch 24/100
# 100/100 [==============================] - 24s 237ms/step - loss: 0.0843 - accuracy: 0.9657 - val_loss: 0.1268 - val_accuracy: 0.9580
# Epoch 25/100
# 100/100 [==============================] - 24s 239ms/step - loss: 0.0756 - accuracy: 0.9650 - val_loss: 0.1829 - val_accuracy: 0.9570
# Epoch 26/100
# 100/100 [==============================] - 24s 238ms/step - loss: 0.0958 - accuracy: 0.9623 - val_loss: 0.1257 - val_accuracy: 0.9550
# Epoch 27/100
# 100/100 [==============================] - 24s 240ms/step - loss: 0.0774 - accuracy: 0.9713 - val_loss: 0.1673 - val_accuracy: 0.9510
# Epoch 28/100
# 100/100 [==============================] - 24s 240ms/step - loss: 0.0684 - accuracy: 0.9707 - val_loss: 0.1186 - val_accuracy: 0.9630
# Epoch 29/100
# 100/100 [==============================] - 24s 236ms/step - loss: 0.0592 - accuracy: 0.9793 - val_loss: 0.1405 - val_accuracy: 0.9670
# Epoch 30/100
# 100/100 [==============================] - 24s 238ms/step - loss: 0.0700 - accuracy: 0.9733 - val_loss: 0.0870 - val_accuracy: 0.9730
# Epoch 31/100
# 100/100 [==============================] - 24s 238ms/step - loss: 0.0708 - accuracy: 0.9690 - val_loss: 0.1355 - val_accuracy: 0.9620
# Epoch 32/100
# 100/100 [==============================] - 24s 237ms/step - loss: 0.0674 - accuracy: 0.9767 - val_loss: 0.1523 - val_accuracy: 0.9670
# Epoch 33/100
# 100/100 [==============================] - 24s 239ms/step - loss: 0.0629 - accuracy: 0.9743 - val_loss: 0.1505 - val_accuracy: 0.9620
# Epoch 34/100
# 100/100 [==============================] - 24s 238ms/step - loss: 0.0611 - accuracy: 0.9753 - val_loss: 0.1365 - val_accuracy: 0.9570
# Epoch 35/100
# 100/100 [==============================] - 24s 238ms/step - loss: 0.0624 - accuracy: 0.9750 - val_loss: 0.1850 - val_accuracy: 0.9580
# Epoch 36/100
# 100/100 [==============================] - 23s 235ms/step - loss: 0.0569 - accuracy: 0.9833 - val_loss: 0.2117 - val_accuracy: 0.9620
# Epoch 37/100
# 100/100 [==============================] - 24s 237ms/step - loss: 0.0655 - accuracy: 0.9747 - val_loss: 0.2135 - val_accuracy: 0.9500
# Epoch 38/100
# 100/100 [==============================] - 24s 239ms/step - loss: 0.0601 - accuracy: 0.9773 - val_loss: 0.2896 - val_accuracy: 0.9460
# Epoch 39/100
# 100/100 [==============================] - 24s 238ms/step - loss: 0.0506 - accuracy: 0.9817 - val_loss: 0.1642 - val_accuracy: 0.9610
# Epoch 40/100
# 100/100 [==============================] - 24s 240ms/step - loss: 0.0528 - accuracy: 0.9817 - val_loss: 0.2045 - val_accuracy: 0.9570
# Epoch 41/100
# 100/100 [==============================] - 24s 238ms/step - loss: 0.0575 - accuracy: 0.9780 - val_loss: 0.1320 - val_accuracy: 0.9680
# Epoch 42/100
# 100/100 [==============================] - 24s 236ms/step - loss: 0.0464 - accuracy: 0.9830 - val_loss: 0.1979 - val_accuracy: 0.9600
# Epoch 43/100
# 100/100 [==============================] - 24s 240ms/step - loss: 0.0456 - accuracy: 0.9820 - val_loss: 0.2809 - val_accuracy: 0.9450
# Epoch 44/100
# 100/100 [==============================] - 24s 240ms/step - loss: 0.0479 - accuracy: 0.9800 - val_loss: 0.1425 - val_accuracy: 0.9690
# Epoch 45/100
# 100/100 [==============================] - 24s 238ms/step - loss: 0.0428 - accuracy: 0.9840 - val_loss: 0.2171 - val_accuracy: 0.9550
# Epoch 46/100
# 100/100 [==============================] - 24s 236ms/step - loss: 0.0451 - accuracy: 0.9820 - val_loss: 0.3485 - val_accuracy: 0.9370
# Epoch 47/100
# 100/100 [==============================] - 24s 237ms/step - loss: 0.0498 - accuracy: 0.9817 - val_loss: 0.2212 - val_accuracy: 0.9480
# Epoch 48/100
# 100/100 [==============================] - 24s 237ms/step - loss: 0.0310 - accuracy: 0.9860 - val_loss: 0.2155 - val_accuracy: 0.9670
# Epoch 49/100
# 100/100 [==============================] - 24s 237ms/step - loss: 0.0490 - accuracy: 0.9827 - val_loss: 0.2258 - val_accuracy: 0.9530
# Epoch 50/100
# 100/100 [==============================] - 24s 238ms/step - loss: 0.0434 - accuracy: 0.9840 - val_loss: 0.2564 - val_accuracy: 0.9590
# Epoch 51/100
# 100/100 [==============================] - 23s 235ms/step - loss: 0.0610 - accuracy: 0.9797 - val_loss: 0.2423 - val_accuracy: 0.9500
# Epoch 52/100
# 100/100 [==============================] - 24s 237ms/step - loss: 0.0439 - accuracy: 0.9877 - val_loss: 0.1353 - val_accuracy: 0.9670
# Epoch 53/100
# 100/100 [==============================] - 24s 241ms/step - loss: 0.0415 - accuracy: 0.9840 - val_loss: 0.2949 - val_accuracy: 0.9520
# Epoch 54/100
# 100/100 [==============================] - 24s 238ms/step - loss: 0.0393 - accuracy: 0.9870 - val_loss: 0.2148 - val_accuracy: 0.9610
# Epoch 55/100
# 100/100 [==============================] - 24s 240ms/step - loss: 0.0360 - accuracy: 0.9853 - val_loss: 0.3026 - val_accuracy: 0.9490
# Epoch 56/100
# 100/100 [==============================] - 24s 236ms/step - loss: 0.0362 - accuracy: 0.9893 - val_loss: 0.2361 - val_accuracy: 0.9550
# Epoch 57/100
# 100/100 [==============================] - 24s 237ms/step - loss: 0.0336 - accuracy: 0.9880 - val_loss: 0.1750 - val_accuracy: 0.9670
# Epoch 58/100
# 100/100 [==============================] - 24s 241ms/step - loss: 0.0300 - accuracy: 0.9900 - val_loss: 0.2262 - val_accuracy: 0.9580
# Epoch 59/100
# 100/100 [==============================] - 24s 242ms/step - loss: 0.0385 - accuracy: 0.9880 - val_loss: 0.1715 - val_accuracy: 0.9660
# Epoch 60/100
# 100/100 [==============================] - 24s 242ms/step - loss: 0.0380 - accuracy: 0.9873 - val_loss: 0.2870 - val_accuracy: 0.9470
# Epoch 61/100
# 100/100 [==============================] - 24s 242ms/step - loss: 0.0254 - accuracy: 0.9900 - val_loss: 0.2575 - val_accuracy: 0.9590
# Epoch 62/100
# 100/100 [==============================] - 24s 239ms/step - loss: 0.0321 - accuracy: 0.9877 - val_loss: 0.1700 - val_accuracy: 0.9750
# Epoch 63/100
# 100/100 [==============================] - 24s 239ms/step - loss: 0.0286 - accuracy: 0.9907 - val_loss: 0.2490 - val_accuracy: 0.9550
# Epoch 64/100
# 100/100 [==============================] - 24s 239ms/step - loss: 0.0303 - accuracy: 0.9897 - val_loss: 0.1949 - val_accuracy: 0.9620
# Epoch 65/100
# 100/100 [==============================] - 24s 241ms/step - loss: 0.0310 - accuracy: 0.9887 - val_loss: 0.1565 - val_accuracy: 0.9600
# Epoch 66/100
# 100/100 [==============================] - 24s 242ms/step - loss: 0.0295 - accuracy: 0.9887 - val_loss: 0.2211 - val_accuracy: 0.9610
# Epoch 67/100
# 100/100 [==============================] - 24s 240ms/step - loss: 0.0269 - accuracy: 0.9903 - val_loss: 0.2290 - val_accuracy: 0.9620
# Epoch 68/100
# 100/100 [==============================] - 24s 238ms/step - loss: 0.0325 - accuracy: 0.9897 - val_loss: 0.2445 - val_accuracy: 0.9590
# Epoch 69/100
# 100/100 [==============================] - 24s 238ms/step - loss: 0.0277 - accuracy: 0.9890 - val_loss: 0.2766 - val_accuracy: 0.9510
# Epoch 70/100
# 100/100 [==============================] - 24s 236ms/step - loss: 0.0297 - accuracy: 0.9893 - val_loss: 0.2437 - val_accuracy: 0.9580
# Epoch 71/100
# 100/100 [==============================] - 24s 236ms/step - loss: 0.0282 - accuracy: 0.9907 - val_loss: 0.3385 - val_accuracy: 0.9530
# Epoch 72/100
# 100/100 [==============================] - 24s 238ms/step - loss: 0.0329 - accuracy: 0.9883 - val_loss: 0.3480 - val_accuracy: 0.9410
# Epoch 73/100
# 100/100 [==============================] - 24s 239ms/step - loss: 0.0340 - accuracy: 0.9910 - val_loss: 0.2213 - val_accuracy: 0.9570
# Epoch 74/100
# 100/100 [==============================] - 24s 237ms/step - loss: 0.0304 - accuracy: 0.9907 - val_loss: 0.3522 - val_accuracy: 0.9470
# Epoch 75/100
# 100/100 [==============================] - 24s 236ms/step - loss: 0.0255 - accuracy: 0.9913 - val_loss: 0.2115 - val_accuracy: 0.9600
# Epoch 76/100
# 100/100 [==============================] - 24s 238ms/step - loss: 0.0309 - accuracy: 0.9903 - val_loss: 0.3855 - val_accuracy: 0.9580
# Epoch 77/100
# 100/100 [==============================] - 24s 236ms/step - loss: 0.0257 - accuracy: 0.9890 - val_loss: 0.2963 - val_accuracy: 0.9500
# Epoch 78/100
# 100/100 [==============================] - 24s 237ms/step - loss: 0.0267 - accuracy: 0.9910 - val_loss: 0.2608 - val_accuracy: 0.9590
# Epoch 79/100
# 100/100 [==============================] - 24s 238ms/step - loss: 0.0295 - accuracy: 0.9887 - val_loss: 0.2461 - val_accuracy: 0.9590
# Epoch 80/100
# 100/100 [==============================] - 24s 239ms/step - loss: 0.0244 - accuracy: 0.9940 - val_loss: 0.2553 - val_accuracy: 0.9580
# Epoch 81/100
# 100/100 [==============================] - 24s 237ms/step - loss: 0.0251 - accuracy: 0.9927 - val_loss: 0.3726 - val_accuracy: 0.9480
# Epoch 82/100
# 100/100 [==============================] - 24s 239ms/step - loss: 0.0332 - accuracy: 0.9890 - val_loss: 0.3139 - val_accuracy: 0.9570
# Epoch 83/100
# 100/100 [==============================] - 24s 239ms/step - loss: 0.0309 - accuracy: 0.9913 - val_loss: 0.2238 - val_accuracy: 0.9660
# Epoch 84/100
# 100/100 [==============================] - 24s 239ms/step - loss: 0.0217 - accuracy: 0.9920 - val_loss: 0.4661 - val_accuracy: 0.9340
# Epoch 85/100
# 100/100 [==============================] - 24s 238ms/step - loss: 0.0223 - accuracy: 0.9920 - val_loss: 0.4027 - val_accuracy: 0.9490
# Epoch 86/100
# 100/100 [==============================] - 24s 240ms/step - loss: 0.0241 - accuracy: 0.9917 - val_loss: 0.2783 - val_accuracy: 0.9630
# Epoch 87/100
# 100/100 [==============================] - 24s 238ms/step - loss: 0.0224 - accuracy: 0.9940 - val_loss: 0.3043 - val_accuracy: 0.9550
# Epoch 88/100
# 100/100 [==============================] - 24s 241ms/step - loss: 0.0225 - accuracy: 0.9943 - val_loss: 0.3265 - val_accuracy: 0.9570
# Epoch 89/100
# 100/100 [==============================] - 24s 239ms/step - loss: 0.0241 - accuracy: 0.9937 - val_loss: 0.2626 - val_accuracy: 0.9620
# Epoch 90/100
# 100/100 [==============================] - 24s 238ms/step - loss: 0.0137 - accuracy: 0.9943 - val_loss: 0.3911 - val_accuracy: 0.9510
# Epoch 91/100
# 100/100 [==============================] - 24s 242ms/step - loss: 0.0233 - accuracy: 0.9920 - val_loss: 0.3175 - val_accuracy: 0.9590
# Epoch 92/100
# 100/100 [==============================] - 24s 236ms/step - loss: 0.0332 - accuracy: 0.9913 - val_loss: 0.3261 - val_accuracy: 0.9530
# Epoch 93/100
# 100/100 [==============================] - 24s 235ms/step - loss: 0.0253 - accuracy: 0.9923 - val_loss: 0.3650 - val_accuracy: 0.9550
# Epoch 94/100
# 100/100 [==============================] - 24s 237ms/step - loss: 0.0281 - accuracy: 0.9927 - val_loss: 0.3551 - val_accuracy: 0.9480
# Epoch 95/100
# 100/100 [==============================] - 24s 238ms/step - loss: 0.0341 - accuracy: 0.9913 - val_loss: 0.3179 - val_accuracy: 0.9540
# Epoch 96/100
# 100/100 [==============================] - 24s 236ms/step - loss: 0.0250 - accuracy: 0.9937 - val_loss: 0.3691 - val_accuracy: 0.9460
# Epoch 97/100
# 100/100 [==============================] - 24s 236ms/step - loss: 0.0295 - accuracy: 0.9917 - val_loss: 0.2861 - val_accuracy: 0.9570
# Epoch 98/100
# 100/100 [==============================] - 24s 240ms/step - loss: 0.0296 - accuracy: 0.9910 - val_loss: 0.3645 - val_accuracy: 0.9520
# Epoch 99/100
# 100/100 [==============================] - 24s 237ms/step - loss: 0.0255 - accuracy: 0.9923 - val_loss: 0.3873 - val_accuracy: 0.9530
# Epoch 100/100
# 100/100 [==============================] - 24s 239ms/step - loss: 0.0328 - accuracy: 0.9910 - val_loss: 0.4068 - val_accuracy: 0.9500

# %%
f, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))
t = f.suptitle('Pre-trained CNN (Transfer Learning) with Fine-Tuning & Image Augmentation Performance', fontsize=12)
f.subplots_adjust(top=0.85, wspace=0.3)

epoch_list = list(range(1,101))
ax1.plot(epoch_list, history.history['accuracy'], label='Train Accuracy')
ax1.plot(epoch_list, history.history['val_accuracy'], label='Validation Accuracy')
ax1.set_xticks(np.arange(0, 101, 10))
ax1.set_ylabel('Accuracy Value')
ax1.set_xlabel('Epoch')
ax1.set_title('Accuracy')
l1 = ax1.legend(loc="best")

ax2.plot(epoch_list, history.history['loss'], label='Train Loss')
ax2.plot(epoch_list, history.history['val_loss'], label='Validation Loss')
ax2.set_xticks(np.arange(0, 101, 10))
ax2.set_ylabel('Loss Value')
ax2.set_xlabel('Epoch')
ax2.set_title('Loss')
l2 = ax2.legend(loc="best")

# %%
from tensorflow.keras.models import load_model

model.save('cats_dogs_tlearn_finetune_img_aug_cnn.h5')

num2class_label_transformer = lambda l: ['cat' if x == 0 else 'dog' for x in l]
class2num_label_transformer = lambda l: [0 if x == 'cat' else 1 for x in l]

# %%
tl_img_aug_finetune_cnn = load_model('cats_dogs_tlearn_finetune_img_aug_cnn.h5')
# Out:
# WARNING:tensorflow:Error in loading the saved optimizer state. As a result, your model is starting with a freshly initialized optimizer.

# %%
IMG_DIM = (150, 150)

test_files = glob.glob('test_data/*')
test_imgs = [img_to_array(load_img(img, target_size=IMG_DIM)) for img in test_files]
test_imgs = np.array(test_imgs)
test_labels = [fn.split('/')[1].split('.')[0].strip() for fn in test_files]

test_imgs_scaled = test_imgs.astype('float32')
test_imgs_scaled /= 255
test_labels_enc = class2num_label_transformer(test_labels)

print('Test dataset shape:', test_imgs.shape)
print(test_labels[0:5], test_labels_enc[0:5])
# Out:
# Test dataset shape: (1000, 150, 150, 3)
# ['cat', 'cat', 'cat', 'cat', 'dog'] [0, 0, 0, 0, 1]

# %%
 from model_evaluation_utils import display_model_performance_metrics

# %%
predictions = tl_img_aug_finetune_cnn.predict_classes(test_imgs_scaled, verbose=0)
predictions = num2class_label_transformer(predictions)
display_model_performance_metrics(true_labels=test_labels, predicted_labels=predictions, 
                                      classes=list(set(test_labels)))
# Out:
# Model Performance metrics:
# ------------------------------
# Accuracy: 0.96
# Precision: 0.9617
# Recall: 0.96
# F1 Score: 0.96
#
# Model Classification report:
# ------------------------------
#               precision    recall  f1-score   support
#
#          cat       0.99      0.93      0.96       500
#          dog       0.93      0.99      0.96       500
#
#     accuracy                           0.96      1000
#    macro avg       0.96      0.96      0.96      1000
# weighted avg       0.96      0.96      0.96      1000
#
#
# Prediction Confusion Matrix:
# ------------------------------
#             Predicted:
#                    cat  dog
# Actual: cat        465   35
#         dog          5  495
# /content/model_evaluation_utils.py:63: FutureWarning: the 'labels' keyword is deprecated, use 'codes' instead
#   labels=level_labels),
# /content/model_evaluation_utils.py:65: FutureWarning: the 'labels' keyword is deprecated, use 'codes' instead
#   labels=level_labels))
